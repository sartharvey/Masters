# %%
# %pip install --upgrade uncertainties
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import caesar
import numpy as np
import astropy
from astropy import constants as const
from astropy import units as u
from astropy.table import QTable, Table, Column
import matplotlib.pyplot as plt
import os
import scipy
from scipy import stats
import seaborn as sns
import uncertainties as unc  
import uncertainties.unumpy as unumpy
from scipy.stats import binned_statistic_2d
import matplotlib
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/sarah/anaconda3/lib/python3.9/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/sarah/.config/yt/ytrc is deprecated in favor of /home/sarah/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
def get_properties(obj):
    ''' 
    Returns the properties x-ray luminosities, stellar mass, star formation rate, specific star formation rate, 
    black hole mass, and lambda for every galaxy in the input file with stellar mass greater than 10^10 solar masses

        Parameters:
                obj : Caesar read infile
                      

        Returns:
                          Lx : array_like
                               An array of x-ray luminosities
                stellar_mass : array_like
                               An array of stellar masses
                         SFR : array_like
                               An array of star formation rates
                        sSFR : array_like
                               An array of specific star formation rates
                     bh_mass : array_like
                               An array of black hole masses
                       lmbda : array_like
                               An array of lambda
                        Ledd : array_like
                               An array of eddington accretion
    '''
    
    # get Lx
    # get an array of all bhmdot and bh_fedd
    accretion_rates = [i.bhmdot for i in obj.galaxies]
    eddington_ratio = [i.bh_fedd for i in obj.galaxies]

    # extract data into array
    bhmdot = np.array(accretion_rates)
    bh_fedd = np.array(eddington_ratio)
    
    # finding Ledd
    Ledd = bhmdot/bh_fedd
    
    # finding the bolometric luminosities
    # array with shape bhmdot of Lbols using the first equation (fedd > 0.1) for all values
    Er = 0.1
    Lbol = ((Er/(1-Er))*bhmdot*(u.M_sun/u.yr)*(const.c**2))
    
    # replacing the indices where fedd < 0.1 with values using the other equation
    # this retains the units
    Lbol[bh_fedd < 0.1] = (10*bh_fedd[bh_fedd < 0.1])*Er*bhmdot[bh_fedd < 0.1]*(u.M_sun/u.yr)*(const.c**2)
    
    # finds the bolometric correction
    BC = 10.83*((Lbol.to('L_sun')/(10**(10)*u.L_sun))**(0.28)) + 6.08*((Lbol.to('L_sun')/(10**(10)*u.L_sun))**(-0.02))
    
    # finding the hard x-ray luminosity in terms of Lsun
    # have to use just the value of Lbol_sun then add it back on because np.log10 only works on dimensionless quantities
    # it then converts to erg/s
    Lx_ergs = ((10**(np.log10(Lbol.to('L_sun').value)-np.log10(BC)))*u.L_sun).to('erg/s')
    
    #making it unitless
    Lx = Lx_ergs.value
    
    
    
    
    # extract galaxy mass data
    galaxy_masses = [i.masses['stellar'] for i in obj.galaxies]
    all_sm = np.array(galaxy_masses)
    sm_gt10 = (all_sm > 10**10)
    stellar_mass = all_sm[sm_gt10]
    
    # masking Lx for corresponding stellar masses > 10^10
    Lx = Lx[sm_gt10]
    
    # masking Ledd for corresponding stellar masses > 10^10
    Ledd = Ledd[sm_gt10]
    
    # masking fedd for corresponding stellar masses > 10^10
    bh_fedd = bh_fedd[sm_gt10]
    
    bhmdot = bhmdot[sm_gt10]
    
    # extract star formation rates data
    galaxy_SFRs = [i.sfr for i in obj.galaxies]
    SFR = np.array(galaxy_SFRs)
    SFR = SFR[sm_gt10]
    
    # extract black hole mass data
    bh_masses = [i.masses['bh'] for i in obj.galaxies]
    bh_mass = np.array(bh_masses)
    bh_mass = bh_mass[sm_gt10]
    
    # calculate specific star formation rate
    sSFR = SFR/stellar_mass
    
    # calculating lambda
    lmbda = 25.0*Lx / (1.3e38*0.002*stellar_mass)  
    
    
    return Lx, stellar_mass, SFR, sSFR, bh_mass, lmbda, Ledd, bh_fedd, bhmdot

# %%
# a list of the different redshifted files I want to load (box size 100)
files = ['m100n1024_056.hdf5',
'm100n1024_066.hdf5',
'm100n1024_074.hdf5',
'm100n1024_084.hdf5',
'm100n1024_097.hdf5',
'm100n1024_114.hdf5',
'm100n1024_137.hdf5']
files.reverse()

# %%
def get_all_r():
    # define input file
    # box 25
    #folder_path = '/disk04/rad/sim/m25n256/s50/Groups/' 
    #box 100
    folder_path = '/disk04/rad/sim/m100n1024/s50/Groups/'

    # empty dictionary to place redshift table data into
    all_r = {}

    for filename in files:
        # load in input file
        obj = caesar.load(os.path.join(folder_path, filename))

        # obtaining the properties
        Lx, sm, SFR, sSFR, bhm, lmbda, Ledd, fedd, BHAR = get_properties(obj)

        # finding the z label
        label = filename.split('m100n1024_')[1].split('.hdf5')[0]

        # creating a table for each redshift, putting it in the empty dictionary, and naming them
        name = str('z') + str(label)
        all_r[name] = astropy.table.Table([Lx, sm, SFR, sSFR, bhm, lmbda, Ledd, fedd, BHAR], 
                                          names=('Lx', 'sm', 'SFR', 'sSFR', 'bhm', 'lambda', 'Ledd', 'fedd', 'BHAR'))
        
    return all_r

# %%
def find_fracs(lambdas, Lx):
    '''
    Finds the percentage of galaxies with lambda greater than 0.01 and 0.1 AND Lx greater than 10^42 for a given set 
    of galaxies defined by their input log lambdas.
    
    Parameters:
                lambdas : array_like
                          An array of log(lambdas)
                      

        Returns:
                frac_gt2 : float
                           The percentage of galaxies with lambda greater than 0.01 AND Lx greater than 10^42
                frac_gt1 : float
                           The percentage of galaxies with lambda greater than 0.1 AND Lx greater than 10^42
                           
    
    '''
    mask2 = (lambdas > -2) & (Lx > 1e42)
    l_gr2 = lambdas[mask2]
            
    if len(l_gr2) == 0:
        #print('there are no lambdas>0.01')
        frac_gt2 = float('NaN')
    else:
        frac_gt2 = (len(l_gr2)/len(lambdas))*100

    mask1 = (lambdas > -1) & (Lx > 1e42)
    l_gr1 = lambdas[mask1]

    if len(l_gr1) == 0:
        #print('there are no lambdas>0.1')
        frac_gt1 = float('Nan')
    else:
        frac_gt1 = (len(l_gr1)/len(lambdas))*100

    #print(frac_gt2)
    #print(frac_gt1)
    
    return frac_gt2, frac_gt1

# %%
#0.01
z = [0.25, 0.75, 1.25, 1.75, 2.25]
jSFR_bins = np.reshape(np.flip(np.array([2.525, 1.98, 1.289, 0.32, -0.703, 2.126, 1.739, 0.98, -0.017, 
          -1.022, 1.833, 1.433, 0.703, -0.378, -1.519, 1.564, 1.088, 0.467, 
          -0.716, -1.932, 1.196, 0.651, 0.08, -0.884, -2.636])), (5,5))
jAGN_fracs_gt2 = np.reshape(np.flip(np.array([23.992, 12.484, 23.354, 13.015, 10.793, 9.974, 10.638,
         16.218, 8.192, 4.12, 9.142, 6.743, 13.323, 4.89, 2.501,
         5.931, 3.617, 5.843, 1.469, 0.934, 3.525, 1.153, 0.696,
         0.418, 0.218])), (5,5))
#0.1
jAGN_fracs_gt1 = np.reshape(np.flip(np.array([13.02, 2.62, 7.133, 3.277, 1.071, 2.87, 1.598, 3.611, 1.349,
          0.4, 2.335, 1.025, 1.635, 0.414, 0.144, 1.48, 0.249, 0.387,
          0.148, 0.025, 0.905, 0.056, 0.046, 0.085, 0.027])), (5,5))

lo_err_gt1 = np.array([2.505, 0.336, 1.089, 0.895, 0.407, 0.445, 0.166, 0.477, 0.283, 0.128, 0.337,
                       0.099, 0.271, 0.109, 0.053, 0.294, 0.037, 0.089, 0.05, 0.014, 0.417, 0.03,
                       0.03, 0.054, 0.018])
hi_err_gt1 = np.array([2.631, 0.392, 1.26, 1.091, 0.57, 0.508, 0.17, 0.57, 0.316, 0.183, 0.389, 0.103,
                       0.318, 0.135, 0.074, 0.368, 0.045, 0.12, 0.077, 0.027, 0.754, 0.053, 0.068,
                       0.144, 0.048])



lo_err_gt2 = np.array([3.788, 1.278, 2.644, 2.957, 2.586, 1.641, 0.796, 1.69, 1.202, 0.843, 1.242,
                       0.381, 1.063, 0.678, 0.423, 0.814, 0.214, 0.492, 0.277, 0.169, 1.189, 0.208,
                       0.196, 0.182, 0.082])
hi_err_gt2 = np.array([4.416, 1.335, 2.808, 3.261, 3.153, 1.675, 0.784, 1.791, 1.245, 0.947, 1.379,
                       0.402, 1.124, 0.788, 0.501, 0.897, 0.218, 0.492, 0.327, 0.198, 1.544, 0.229,
                       0.25, 0.284,0.125])


lo_err_gt1 = np.flip(lo_err_gt1)
lo_err_gt2 = np.flip(lo_err_gt2)

hi_err_gt1 = np.flip(hi_err_gt1)
hi_err_gt2 = np.flip(hi_err_gt2)
#print(np.split(lo_err_gt1, 5))

lo_err_gt1 = np.split(lo_err_gt1, 5)
lo_err_gt2 = np.split(lo_err_gt2, 5)

hi_err_gt1 = np.split(hi_err_gt1, 5)
hi_err_gt2 = np.split(hi_err_gt2, 5)

err_bounds_allz = []
lo_bounds_allz = []
up_bounds_allz = []
for z in range(len(jAGN_fracs_gt2)):
    jfracs2_lo = unumpy.uarray((jAGN_fracs_gt2[z], lo_err_gt2[z]))  
    jfracs1_lo = unumpy.uarray((jAGN_fracs_gt1[z], lo_err_gt1[z]))
    vari_lo = jfracs1_lo/jfracs2_lo
    prop_err_lo = unumpy.std_devs(vari_lo)

    jfracs2_hi = unumpy.uarray((jAGN_fracs_gt2[z], hi_err_gt2[z]))  
    jfracs1_hi = unumpy.uarray((jAGN_fracs_gt1[z], hi_err_gt1[z]))
    vari_hi = jfracs1_hi/jfracs2_hi
    prop_err_hi = unumpy.std_devs(vari_hi)

    err_bounds = np.vstack((prop_err_lo,prop_err_hi))
    
    lo_bounds = jAGN_fracs_gt1[z]/jAGN_fracs_gt2[z] - err_bounds[0]
    up_bounds = jAGN_fracs_gt1[z]/jAGN_fracs_gt2[z] + err_bounds[1]
    
    err_bounds_allz.append(err_bounds)
    lo_bounds_allz.append(lo_bounds)
    up_bounds_allz.append(up_bounds)

# %%
all_r = get_all_r()
#print(all_r)
# Out:
# yt : [INFO     ] 2023-03-19 14:55:30,865 Opening /disk04/rad/sim/m100n1024/s50/Groups/m100n1024_137.hdf5
# yt : [INFO     ] 2023-03-19 14:55:30,930 Found 482650 halos
# yt : [INFO     ] 2023-03-19 14:55:30,940 Found 49752 galaxies
# yt : [INFO     ] 2023-03-19 14:55:33,825 Opening /disk04/rad/sim/m100n1024/s50/Groups/m100n1024_114.hdf5
# yt : [INFO     ] 2023-03-19 14:55:33,858 Found 517907 halos
# yt : [INFO     ] 2023-03-19 14:55:33,867 Found 41585 galaxies
# yt : [INFO     ] 2023-03-19 14:55:36,080 Opening /disk04/rad/sim/m100n1024/s50/Groups/m100n1024_097.hdf5
# yt : [INFO     ] 2023-03-19 14:55:36,113 Found 539783 halos
# yt : [INFO     ] 2023-03-19 14:55:36,122 Found 37280 galaxies
# yt : [INFO     ] 2023-03-19 14:55:38,509 Opening /disk04/rad/sim/m100n1024/s50/Groups/m100n1024_084.hdf5
# yt : [INFO     ] 2023-03-19 14:55:38,540 Found 547198 halos
# yt : [INFO     ] 2023-03-19 14:55:38,552 Found 33282 galaxies
# ...

# %%
def prob_dists(sigma):
    
        #all_r = get_all_r()
        z = [0.25, 0.75, 1.25, 1.75, 2.25, 2.75, 3.5]

        # lists to store the 6 agn fractions (each redshift)
        #AGN_fracs_gt2 = []
        #AGN_fracs_gt1 = []
        p_lams = np.array([])

        # list to store the 6 sfr bin midpoints for plotting
        #SFR_bins = []

        #iterating across each redshift
        for count, key in enumerate(all_r):

            #
            #AGN_frac_per_bin_gt2 = np.array([])
            #AGN_frac_per_bin_gt1 = np.array([])
            p_lam_per_bin = []

            #extract xray luminosities to make mask Lx> 10^42
            Lx = all_r[key]['Lx'].copy()

            no_zeros = (Lx!=0)

            Lx = Lx[no_zeros]

            sm = all_r[key]['sm'][no_zeros].copy()
            logsm = np.log10(sm.data)

            # NEW WAY: binning the mass data
            #extracting the sfrs for this redshift
            SFRs_all = all_r[key]['SFR'][no_zeros].copy()
            SFRs = SFRs_all

            #creating an empty array with the size equal to the amount of 0 sfr values
            rand_sams = np.zeros(SFRs[SFRs == 0].shape)

            #filling the empty array with random numbers ranging between 0.000001 and 0.00001
            for i in range(len(rand_sams)):
                rand_sams[i] = np.random.uniform(1e-3, 1e-2)

            #replacing 0 sfr values with the randomly sampled low values
            SFRs[SFRs == 0] = rand_sams

            #logging the full sfr array with 0 values replaced
            logSFRs = np.log10(np.asarray(SFRs))

            #calculating relative MS values
            logSFR_MS = logSFRs + 7.6 - 0.76*logsm - 2.95*np.log10(1+z[count])

            #defining bin boundaries
            bins = [np.inf, 0.15, -0.4, -0.95, -np.inf]

            #binning data based on relative MS values
            digitized = np.digitize(logSFR_MS, bins)

            # finding plotting points
            #SFRs_midpoints = np.array([])

            # iterating across each bin
            for i in range(1, len(bins)):
                # finding the lambdas in a certain bin
                lmbda = all_r[key]['lambda'][no_zeros].copy()
                lambdas = np.log10(lmbda[digitized == i])
                lambdas = lambdas.tolist()
                #plt.hist(lambdas, bins=100)
                #plt.show()


                '''        
                #ADDING SCATTER
                '''
                #mu = np.mean(lambdas)
                #sigma = sigma

                #print('loglams:', lambdas)
                #print('mean:', mu)
                #print('stdev:', sigma)

                #print(lambdas.size)
                #np.random.seed(999)
                #new_lambdas = lambdas + np.random.normal(0, sigma, lambdas.size)
                #new_lambdas = np.random.poisson(mu, lambdas.size)


                # finding the Lxs in a certain bin
                Lx_binned = Lx[digitized == i]
                # finding the agn fractions (2) for a certain bin
                #frac_gt2, frac_gt1 = find_fracs(new_lambdas, Lx_binned)

                #binning sfrs
                #sfr_binned = logSFRs[digitized == i]
                #SFRs_midpoints = np.append(SFRs_midpoints, np.median(sfr_binned))

                #adding the agn fraction of each bin to an array length 5 (no of bins)
                #AGN_frac_per_bin_gt2 = np.append(AGN_frac_per_bin_gt2, frac_gt2)
                #AGN_frac_per_bin_gt1 = np.append(AGN_frac_per_bin_gt1, frac_gt1)
                p_lam_per_bin.append(lambdas)

            p_lam_per_bin = np.asarray(p_lam_per_bin, dtype=object)
            #print(p_lam_per_bin)
            #SFR_bins.append(SFRs_midpoints)
            # adding the certain redshifts agn fraction for each bin, into an array length 6 (no of redshifts)
            #AGN_fracs_gt2.append(AGN_frac_per_bin_gt2)
            #AGN_fracs_gt1.append(AGN_frac_per_bin_gt1)
            if count==0:
                p_lams = p_lam_per_bin
            else:
                p_lams = np.vstack((p_lams, p_lam_per_bin))
            
            #this might not work becayse the redshift lists are different lengths
            #fracs2 = np.array(AGN_fracs_gt2)
            #fracs1 = np.array(AGN_fracs_gt1)
            
            #variations = fracs1/fracs2
            #print(variations)
            
        return p_lams

# %%
import colorsys

def scale_lightness(rgb, scale_l):
    # convert rgb to hls
    h, l, s = colorsys.rgb_to_hls(*rgb)
    # manipulate h, l, s values and return as rgb
    return colorsys.hls_to_rgb(h, min(1, l * scale_l), s = s)

orange = matplotlib.colors.ColorConverter.to_rgb("#ff7f0e")
#blue = matplotlib.colors.ColorConverter.to_rgb("#1f77b4")
green = matplotlib.colors.ColorConverter.to_rgb("#2ca02c")
#purple = matplotlib.colors.ColorConverter.to_rgb("#9467bd")
#red = matplotlib.colors.ColorConverter.to_rgb('#d62728')
#pink = matplotlib.colors.ColorConverter.to_rgb('#e377c2')

blue = matplotlib.colors.ColorConverter.to_rgb('blue')
purple = matplotlib.colors.ColorConverter.to_rgb("darkviolet")
pink = matplotlib.colors.ColorConverter.to_rgb('fuchsia')
red = matplotlib.colors.ColorConverter.to_rgb('red')
darkred = matplotlib.colors.ColorConverter.to_rgb('darkred')

# %%
#AGN_fracs_gt2, AGN_fracs_gt1, SFR_bins = agn_fracs(0.263)
#AGN_fracs_gt20, AGN_fracs_gt10, SFR_bins0 = agn_fracs(0)
p_lams = prob_dists(0)

# %%
print(len(p_lams))
# Out:
# 7

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, sharey='all', figsize=(16,8))

sns.distplot(p_lams[0,0], hist=False, kde=True, bins=100, color=blue, label='Starburst', ax=ax1)
sns.distplot(p_lams[0,1], hist=False, kde=True, bins=100, color=purple, label='Main Sequence', ax=ax1)
sns.distplot(p_lams[0,2], hist=False, kde=True, bins=100, color=pink, label='Sub-MS', ax=ax1)
sns.distplot(p_lams[0,3], hist=False, kde=True, bins=100, color=red, label='Quiescent', ax=ax1)

sns.distplot(p_lams[1,0], hist=False, kde=True, bins=100, color=blue, ax=ax2)
sns.distplot(p_lams[1,1], hist=False, kde=True, bins=100, color=purple,  ax=ax2)
sns.distplot(p_lams[1,2], hist=False, kde=True, bins=100, color=pink,  ax=ax2)
sns.distplot(p_lams[1,3], hist=False, kde=True, bins=100, color=red, ax=ax2)

sns.distplot(p_lams[2,0], hist=False, kde=True, bins=100, color=blue,  ax=ax3)
sns.distplot(p_lams[2,1], hist=False, kde=True, bins=100, color=purple, ax=ax3)
sns.distplot(p_lams[2,2], hist=False, kde=True, bins=100, color=pink,  ax=ax3)
sns.distplot(p_lams[2,3], hist=False, kde=True, bins=100, color=red,  ax=ax3)

sns.distplot(p_lams[3,0], hist=False, kde=True, bins=100, color=blue, ax=ax4)
sns.distplot(p_lams[3,1], hist=False, kde=True, bins=100, color=purple,  ax=ax4)
sns.distplot(p_lams[3,2], hist=False, kde=True, bins=100, color=pink,  ax=ax4)
sns.distplot(p_lams[3,3], hist=False, kde=True, bins=100, color=red,  ax=ax4)

sns.distplot(p_lams[4,0], hist=False, kde=True, bins=100, color=blue, ax=ax5)
sns.distplot(p_lams[4,1], hist=False, kde=True, bins=100, color=purple, ax=ax5)
sns.distplot(p_lams[4,2], hist=False, kde=True, bins=100, color=pink, ax=ax5)
sns.distplot(p_lams[4,3], hist=False, kde=True, bins=100, color=red, ax=ax5)

sns.distplot(p_lams[5,0], hist=False, kde=True, bins=100, color=blue, ax=ax6)
sns.distplot(p_lams[5,1], hist=False, kde=True, bins=100, color=purple, ax=ax6)
sns.distplot(p_lams[5,2], hist=False, kde=True, bins=100, color=pink, ax=ax6)
sns.distplot(p_lams[5,3], hist=False, kde=True, bins=100, color=red, ax=ax6)

sns.distplot(p_lams[6,0], hist=False, kde=True, bins=100, color=blue, ax=ax7)
sns.distplot(p_lams[6,1], hist=False, kde=True, bins=100, color=purple, ax=ax7)
sns.distplot(p_lams[6,2], hist=False, kde=True, bins=100, color=pink, ax=ax7)
sns.distplot(p_lams[6,3], hist=False, kde=True, bins=100, color=red, ax=ax7)

ax1.set_yscale('log')
ax1.set_xlabel('$\log(\lambda_{\mathrm{BHAR}})$')
ax1.set_ylabel('$\log p(\log(\lambda_{\mathrm{BHAR}}))$')
ax1.set_xlim(left=-4, right=0)
ax1.set_ylim(bottom=1E-5, top=10)

ax2.set_xlim(left=-3, right=0.5)
ax3.set_xlim(left=-3, right=1)
ax4.set_xlim(left=-3, right=1)

ax5.set_xlim(left=-2, right=1)
ax6.set_xlim(left=-2, right=1)
ax7.set_xlim(left=-2, right=1)

ax1.set_title('z=0.25')
ax2.set_title('z=0.75')
ax3.set_title('z=1.25')
ax4.set_title('z=1.75')
ax5.set_title('z=2.25')
ax6.set_title('z=2.75')
ax7.set_title('z=3.5')

ax1.tick_params('both', labelbottom=True, labelleft=True)
ax2.tick_params('both', labelbottom=True, labelleft=True)
ax3.tick_params('both', labelbottom=True, labelleft=True)
ax4.tick_params('both', labelbottom=True, labelleft=True)
ax5.tick_params('both', labelbottom=True, labelleft=True)
ax6.tick_params('both', labelbottom=True, labelleft=True)
ax7.tick_params('both', labelbottom=True, labelleft=True)
ax8.tick_params('both', labelbottom=False, labelleft=False)


fig.legend(bbox_to_anchor=(0.9, 0.13), loc='lower right', fontsize='x-large')
plt.show()

# %%
list0 = [1,2,3,4]
list1 = [10,20,30]
list2 = [11,22,33,44,55]
list3 = [6,7]

array4 = np.array([list0, list1, list2, list3], dtype=object)
#print(array4)
z = [0,1,2,3,4,5,6]
array7 = np.array([array4])
for i in z:
    zarray = np.array([array4])
    #print(zarray)
    #if i == 0:
    #array7 = zarray
    #else:
    #    np.hstack((array7, zarray))
    array7 = np.vstack((array7, zarray))
    
print(array7)
#np.reshape(array7, (4,7))
# Out:
# [[list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]
#  [list([1, 2, 3, 4]) list([10, 20, 30]) list([11, 22, 33, 44, 55])
#   list([6, 7])]]

# %%
import colorsys

def scale_lightness(rgb, scale_l):
    # convert rgb to hls
    h, l, s = colorsys.rgb_to_hls(*rgb)
    # manipulate h, l, s values and return as rgb
    return colorsys.hls_to_rgb(h, min(1, l * scale_l), s = s)

orange = matplotlib.colors.ColorConverter.to_rgb("#ff7f0e")
#blue = matplotlib.colors.ColorConverter.to_rgb("#1f77b4")
green = matplotlib.colors.ColorConverter.to_rgb("#2ca02c")
#purple = matplotlib.colors.ColorConverter.to_rgb("#9467bd")
#red = matplotlib.colors.ColorConverter.to_rgb('#d62728')
#pink = matplotlib.colors.ColorConverter.to_rgb('#e377c2')

blue = matplotlib.colors.ColorConverter.to_rgb('blue')
purple = matplotlib.colors.ColorConverter.to_rgb("darkviolet")
pink = matplotlib.colors.ColorConverter.to_rgb('fuchsia')
red = matplotlib.colors.ColorConverter.to_rgb('orangered')
darkred = matplotlib.colors.ColorConverter.to_rgb('firebrick')
lightblue = matplotlib.colors.ColorConverter.to_rgb('deepskyblue')
green = matplotlib.colors.ColorConverter.to_rgb('limegreen')
blue = matplotlib.colors.ColorConverter.to_rgb('royalblue')

# %%
file = open('Aird19_fig9.dat')

#turning the data into an astropy table
dists = astropy.table.Table(np.genfromtxt(file, dtype=None), names=['pop', 'zlo', 'zhi', 'loglambda', 'plo', 'pmed', 'phi'])
#print(dists)

#redshift bins
z025 = (dists['zlo'] == 0.1)
z075 = (dists['zlo'] == 0.5)
z125 = (dists['zlo'] == 1.0)
z175 = (dists['zlo'] == 1.5)
z225 = (dists['zlo'] == 2.0)
z275 = (dists['zlo'] == 2.5)
z350 = (dists['zlo'] == 3.0)

#population bins
qu_lo = (dists['pop'] == 'Quiescent(low)')
qu_hi = (dists['pop'] == 'Quiescent(high)')
sub_ms = (dists['pop'] == 'Sub-MS')
ms = (dists['pop'] == 'MainSequence')
st = (dists['pop'] == 'Starburst')

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2, sharex='all', sharey='all', figsize=(14,6))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
fig.subplots_adjust(wspace=0.3)

sns.distplot(p_lams[1,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax1, label='Starburst')
sns.distplot(p_lams[1,1], hist=False, kde=True, bins=100, color=blue, ax=ax1, label='Main Sequence')
#sns.distplot(p_lams[1,2], hist=False, kde=True, bins=100, color=green, ax=ax2, label='Sub-MS')
sns.distplot(p_lams[1,3], hist=False, kde=True, bins=100, color=red, ax=ax2, label='Quiescent')

ax2.plot(dists['loglambda'][z075 & qu_lo], dists['pmed'][z075 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5), label='Quiescent(low)')
ax2.plot(dists['loglambda'][z075 & qu_hi], dists['pmed'][z075 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
#ax2.plot(dists['loglambda'][z075 & sub_ms], dists['pmed'][z075 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax1.plot(dists['loglambda'][z075 & ms], dists['pmed'][z075 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax1.plot(dists['loglambda'][z075 & st], dists['pmed'][z075 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

ax1.set_xlim(left=-3, right=1)
ax1.set_ylim(bottom=10**(-4), top=2)
ax1.set_yscale('log')
ax2.set_xlim(left=-3, right=1)
ax2.set_ylim(bottom=3*10**(-5), top=1)
ax2.set_yscale('log')

ax1.set_ylabel('$\log \mathrm{p}( \log \lambda_{\mathrm{BHAR}}$)', fontsize='large')
ax1.set_xlabel('$\log \lambda_{\mathrm{BHAR}}$', fontsize='large')
ax2.set_ylabel('$\log \mathrm{p}( \log \lambda_{\mathrm{BHAR}}$)', fontsize='large')
ax2.set_xlabel('$\log \lambda_{\mathrm{BHAR}}$', fontsize='large')

ax1.legend(loc='lower left', fontsize='large')
ax2.legend(loc='lower left', fontsize='large')
fig.suptitle('Probability Density Distributions of $\lambda_{\mathrm{BHAR}}$', fontsize='xx-large')
plt.show()

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2, sharex='all', sharey='all', figsize=(14,6))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
fig.subplots_adjust(wspace=0.3)

sns.distplot(p_lams[2,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax1, label='Starburst')
sns.distplot(p_lams[2,1], hist=False, kde=True, bins=100, color=blue, ax=ax1, label='Main Sequence')
#sns.distplot(p_lams[1,2], hist=False, kde=True, bins=100, color=green, ax=ax2, label='Sub-MS')
sns.distplot(p_lams[2,3], hist=False, kde=True, bins=100, color=red, ax=ax2, label='Quiescent')

ax2.plot(dists['loglambda'][z125 & qu_lo], dists['pmed'][z125 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5), label='Quiescent(low)')
ax2.plot(dists['loglambda'][z125 & qu_hi], dists['pmed'][z125 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
#ax2.plot(dists['loglambda'][z075 & sub_ms], dists['pmed'][z075 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax1.plot(dists['loglambda'][z125 & ms], dists['pmed'][z125 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax1.plot(dists['loglambda'][z125 & st], dists['pmed'][z125 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

ax1.set_xlim(left=-3, right=1)
ax1.set_ylim(bottom=10**(-4), top=2)
ax1.set_yscale('log')
ax2.set_xlim(left=-3, right=1)
ax2.set_ylim(bottom=3*10**(-5), top=1)
ax2.set_yscale('log')

ax1.set_ylabel('$\log \mathrm{p}( \log \lambda_{\mathrm{BHAR}}$)', fontsize='large')
ax1.set_xlabel('$\log \lambda_{\mathrm{BHAR}}$', fontsize='large')
ax2.set_ylabel('$\log \mathrm{p}( \log \lambda_{\mathrm{BHAR}}$)', fontsize='large')
ax2.set_xlabel('$\log \lambda_{\mathrm{BHAR}}$', fontsize='large')

ax1.legend(loc='lower left', fontsize='large')
ax2.legend(loc='upper right', fontsize='large')
fig.suptitle('Probability Density Distributions of $\lambda_{\mathrm{BHAR}}$ (z=1.25)', fontsize='xx-large')
plt.show()

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, sharey='all', sharex='all', figsize=(15,7))
fig.subplots_adjust(wspace=0.3)

sns.distplot(p_lams[0,0], hist=False, kde=True, bins=100, color=lightblue, label='Starburst', ax=ax1, axlabel=None)
sns.distplot(p_lams[0,1], hist=False, kde=True, bins=100, color=blue, label='Main Sequence', ax=ax1, axlabel=None)
sns.distplot(p_lams[0,2], hist=False, kde=True, bins=100, color=green, label='Sub-MS', ax=ax1, axlabel=None)
sns.distplot(p_lams[0,3], hist=False, kde=True, bins=100, color=red, label='Quiescent', ax=ax1, axlabel=None)

ax1.plot(dists['loglambda'][z025 & qu_lo], dists['pmed'][z025 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5), label='Quiescent(low)')
ax1.plot(dists['loglambda'][z025 & qu_hi], dists['pmed'][z025 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax1.plot(dists['loglambda'][z025 & sub_ms], dists['pmed'][z025 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax1.plot(dists['loglambda'][z025 & ms], dists['pmed'][z025 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax1.plot(dists['loglambda'][z025 & st], dists['pmed'][z025 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[1,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax2, axlabel=None)
sns.distplot(p_lams[1,1], hist=False, kde=True, bins=100, color=blue,  ax=ax2, axlabel=None)
sns.distplot(p_lams[1,2], hist=False, kde=True, bins=100, color=green,  ax=ax2, axlabel=None)
sns.distplot(p_lams[1,3], hist=False, kde=True, bins=100, color=red, ax=ax2, axlabel=None)

ax2.plot(dists['loglambda'][z075 & qu_lo], dists['pmed'][z075 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax2.plot(dists['loglambda'][z075 & qu_hi], dists['pmed'][z075 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax2.plot(dists['loglambda'][z075 & sub_ms], dists['pmed'][z075 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax2.plot(dists['loglambda'][z075 & ms], dists['pmed'][z075 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax2.plot(dists['loglambda'][z075 & st], dists['pmed'][z075 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[2,0], hist=False, kde=True, bins=100, color=lightblue,  ax=ax3, axlabel=None)
sns.distplot(p_lams[2,1], hist=False, kde=True, bins=100, color=blue, ax=ax3, axlabel=None)
sns.distplot(p_lams[2,2], hist=False, kde=True, bins=100, color=green,  ax=ax3, axlabel=None)
sns.distplot(p_lams[2,3], hist=False, kde=True, bins=100, color=red,  ax=ax3, axlabel=None)

ax3.plot(dists['loglambda'][z125 & qu_lo], dists['pmed'][z125 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax3.plot(dists['loglambda'][z125 & qu_hi], dists['pmed'][z125 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax3.plot(dists['loglambda'][z125 & sub_ms], dists['pmed'][z125 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax3.plot(dists['loglambda'][z125 & ms], dists['pmed'][z125 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax3.plot(dists['loglambda'][z125 & st], dists['pmed'][z125 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[3,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax4,axlabel=None)
sns.distplot(p_lams[3,1], hist=False, kde=True, bins=100, color=blue,  ax=ax4,axlabel=None)
sns.distplot(p_lams[3,2], hist=False, kde=True, bins=100, color=green,  ax=ax4, axlabel=None)
sns.distplot(p_lams[3,3], hist=False, kde=True, bins=100, color=red,  ax=ax4,axlabel=None)

ax4.plot(dists['loglambda'][z175 & qu_lo], dists['pmed'][z175 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax4.plot(dists['loglambda'][z175 & qu_hi], dists['pmed'][z175 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax4.plot(dists['loglambda'][z175 & sub_ms], dists['pmed'][z175 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax4.plot(dists['loglambda'][z175 & ms], dists['pmed'][z175 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax4.plot(dists['loglambda'][z175 & st], dists['pmed'][z175 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[4,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax5, axlabel=None)
sns.distplot(p_lams[4,1], hist=False, kde=True, bins=100, color=blue, ax=ax5, axlabel=None)
sns.distplot(p_lams[4,2], hist=False, kde=True, bins=100, color=green, ax=ax5, axlabel=None)
sns.distplot(p_lams[4,3], hist=False, kde=True, bins=100, color=red, ax=ax5, axlabel=None)

ax5.plot(dists['loglambda'][z225 & qu_lo], dists['pmed'][z225 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax5.plot(dists['loglambda'][z225 & qu_hi], dists['pmed'][z225 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax5.plot(dists['loglambda'][z225 & sub_ms], dists['pmed'][z225 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax5.plot(dists['loglambda'][z225 & ms], dists['pmed'][z225 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax5.plot(dists['loglambda'][z225 & st], dists['pmed'][z225 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[5,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax6, axlabel=None)
sns.distplot(p_lams[5,1], hist=False, kde=True, bins=100, color=blue, ax=ax6, axlabel=None)
sns.distplot(p_lams[5,2], hist=False, kde=True, bins=100, color=green, ax=ax6, axlabel=None)
sns.distplot(p_lams[5,3], hist=False, kde=True, bins=100, color=red, ax=ax6, axlabel=None)

ax6.plot(dists['loglambda'][z275 & qu_lo], dists['pmed'][z275 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax6.plot(dists['loglambda'][z275 & qu_hi], dists['pmed'][z275 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax6.plot(dists['loglambda'][z275 & sub_ms], dists['pmed'][z275 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax6.plot(dists['loglambda'][z275 & ms], dists['pmed'][z275 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax6.plot(dists['loglambda'][z275 & st], dists['pmed'][z275 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

sns.distplot(p_lams[6,0], hist=False, kde=True, bins=100, color=lightblue, ax=ax7, axlabel=None)
sns.distplot(p_lams[6,1], hist=False, kde=True, bins=100, color=blue, ax=ax7, axlabel=None)
sns.distplot(p_lams[6,2], hist=False, kde=True, bins=100, color=green, ax=ax7, axlabel=None)
sns.distplot(p_lams[6,3], hist=False, kde=True, bins=100, color=red, ax=ax7,axlabel=None)

ax7.plot(dists['loglambda'][z350 & qu_lo], dists['pmed'][z350 & qu_lo], linestyle='--', color=scale_lightness(darkred, 1.5))
ax7.plot(dists['loglambda'][z350 & qu_hi], dists['pmed'][z350 & qu_hi], linestyle='--', color=scale_lightness(red, 1.3))
ax7.plot(dists['loglambda'][z350 & sub_ms], dists['pmed'][z350 & sub_ms], linestyle='--', color=scale_lightness(green, 1.5))
ax7.plot(dists['loglambda'][z350 & ms], dists['pmed'][z350 & ms], linestyle='--', color=scale_lightness(blue, 1.3))
ax7.plot(dists['loglambda'][z350 & st], dists['pmed'][z350 & st], linestyle='--', color=scale_lightness(lightblue, 1.3))

ax1.set_yscale('log')
ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
ax4.set_ylabel('')
ax5.set_ylabel('')
ax6.set_ylabel('')
ax7.set_ylabel('')
#ax1.sety_ylabel('$\log p(\log(\lambda_{\mathrm{BHAR}}))$')
ax1.set_xlim(left=-4, right=0)
ax1.set_ylim(bottom=1E-5, top=10)

ax2.set_xlim(left=-3, right=0.5)
ax3.set_xlim(left=-3, right=1)
ax4.set_xlim(left=-3, right=1)

ax5.set_xlim(left=-2, right=1)
ax6.set_xlim(left=-2, right=1)
ax7.set_xlim(left=-2, right=1)

ax1.set_title('z=0.25')
ax2.set_title('z=0.75')
ax3.set_title('z=1.25')
ax4.set_title('z=1.75')
ax5.set_title('z=2.25')
ax6.set_title('z=2.75')
ax7.set_title('z=3.5')

ax1.tick_params('both', labelbottom=True, labelleft=True)
ax2.tick_params('both', labelbottom=True, labelleft=True)
ax3.tick_params('both', labelbottom=True, labelleft=True)
ax4.tick_params('both', labelbottom=True, labelleft=True)
ax5.tick_params('both', labelbottom=True, labelleft=True)
ax6.tick_params('both', labelbottom=True, labelleft=True)
ax7.tick_params('both', labelbottom=True, labelleft=True)
ax8.tick_params('both', labelbottom=False, labelleft=False)

fig.text(0.5, 0.05, '$\log(\lambda_{\mathrm{BHAR}})$', ha='center', fontsize='xx-large')
fig.text(0.075, 0.5, '$\log p(\log(\lambda_{\mathrm{BHAR}}))$', va='center', rotation='vertical', fontsize='xx-large')

fig.legend(bbox_to_anchor=(0.9, 0.13), loc='lower right', fontsize='x-large')
plt.show()

# %%
plt.plot(0,0, color=lightblue, label='Starburst')
plt.plot(0,0, color=blue, label='Main Sequence')
plt.plot(0,0, color=green, label='Sub-MS')
plt.plot(0,0, color=red, label='Quiescent')
plt.plot(0,0, linestyle='--', color=scale_lightness(darkred, 1.5), label='Quiescent(low)')
plt.legend(fontsize='xx-large')
plt.show()
